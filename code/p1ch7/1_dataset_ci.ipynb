# %%
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
data_path = r'D:\Project\PyProject\pytorch_example\code\data\p1ch7'
cifar10 = datasets.CIFAR10(data_path, train=True, download=False, transform=transforms.ToTensor())
print(cifar10)
cifar10_val = datasets.CIFAR10(data_path, train=False, download=False, transform=transforms.ToTensor())
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: D:\Project\PyProject\pytorch_example\code\data\p1ch7
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
# print(len(cifar10_val))
img, _ = cifar10_val[99]
# plt.imshow(img)
# plt.show()
# target
# dir(transforms)
print(img.shape, img.min(), img.max())
plt.imshow(img.permute(1,2,0))
plt.show()
# Out:
# torch.Size([3, 32, 32]) tensor(0.1216) tensor(1.)

# %%
import torch

imgs = torch.stack([img_t for img_t, _ in cifar10], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
imgs.view(3, -1).mean(dim=1), imgs.view(3, -1).std(dim=1)
# Out:
# (tensor([0.4914, 0.4822, 0.4465]), tensor([0.2470, 0.2435, 0.2616]))

# %%
transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))])
imgs_t, _ = cifar10[0]
plt.imshow(imgs_t.permute(1,2,0))
plt.show()
